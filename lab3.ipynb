# %%
# change directory to 
# %cd ~/Documents/cvprlab/
# Out:
# /Users/canali/Documents/cvprlab

# %%
print(image_paths)
# Out:
# ['./MSRC_ObjCategImageDatabase_v2/Images/8_22_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/12_29_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/17_20_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/11_5_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/12_15_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/20_1_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/9_16_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/5_27_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/3_26_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/18_23_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/17_27_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/5_29_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/3_28_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/20_12_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/13_7_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/19_21_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/13_22_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/7_18_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/4_26_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/9_12_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/10_18_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/2_25_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/9_15_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/20_10_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/14_28_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/9_23_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/2_13_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/18_13_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/12_14_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/2_16_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/4_25_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/8_1_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/9_21_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/4_20_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/11_3_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/14_18_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/13_16_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/4_21_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/12_20_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/2_4_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/14_1_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/12_4_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/18_12_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/2_6_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/2_11_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/12_12_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/5_1_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/13_30_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/6_4_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/18_7_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/17_18_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/7_7_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/9_5_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/9_4_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/16_28_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/5_6_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/4_23_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/5_9_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/8_2_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/10_29_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/12_32_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/17_24_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/7_20_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/18_2_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/2_5_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/16_27_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/8_10_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/14_17_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/3_19_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/5_7_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/3_3_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/20_18_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/6_1_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/5_19_s.bmp', './MSRC_ObjCategImageDatabase_v2/Images/7_21_s.bmp', './MSRC_ObjC ...

# %%
# FEATURE EXTRACTION

import cv2
import numpy as np
import os
import glob

import matplotlib.pyplot as plt
def extract_color_descriptor(img):
    # Compute the average red, green, and blue values as a basic color descriptor
    R = np.mean(img[:, :, 2])  # Note: OpenCV uses BGR format
    G = np.mean(img[:, :, 1])
    B = np.mean(img[:, :, 0])
    return np.array([R, G, B])

def extract_color_hist_descriptor(img, bin_number):
    red_hist, bins_red = np.histogram(img[:,:,2], bins=bin_number, range=(0,255))
    green_hist, bins_green = np.histogram(img[:,:,1], bins=bin_number, range=(0,255))
    blue_hist, bins_blue = np.histogram(img[:,:,0], bins=bin_number, range=(0,255))
    # plt.figure(figsize=(10, 5))

    # plt.subplot(3, 1, 1)
    # plt.bar(bins_red[:-1], red_hist, width=np.diff(bins_red), color='red', edgecolor='black', align='edge')


    # plt.subplot(3, 1, 2)
    # plt.bar(bins_green[:-1], green_hist, width=np.diff(bins_green), color='green', edgecolor='black', align='edge')


    # plt.subplot(3, 1, 3)
    # plt.bar(bins_blue[:-1], blue_hist, width=np.diff(bins_blue), color='blue', edgecolor='black', align='edge')

    # plt.tight_layout()
    # plt.show()
    return np.concatenate((red_hist, green_hist, blue_hist))
    # return np.array([red_hist,green_hist,blue_hist])
# Ex1: Download the Skeleton code and Dataset
DATASET_FOLDER = './MSRC_ObjCategImageDatabase_v2/Images/'  # Modify this path as needed
OUT_FOLDER = './python/descriptors/better_descriptors/'  # Modify this path as needed
if not os.path.exists(OUT_FOLDER):
    os.makedirs(OUT_FOLDER)
image_paths = glob.glob(DATASET_FOLDER + "*.bmp", recursive=True)

for image_path in image_paths:
    image = cv2.imread(image_path)
    #feature = extract_color_descriptor(image)
    feature = extract_color_hist_descriptor(image, 8)

    save_path = image_path.split('/')[-1].split('.')[0] + '.npy' # extract filename add .npy extension
    np.save(OUT_FOLDER + save_path, feature)

# Print results of Ex3: Display the filenames of the top 20 matching images
# print("Top 20 matching images:")
# for index in top_indices:
#     print(image_files[index])

# Ex4: Modify the Distance measure
# Here we can use Euclidean distance. For other measures modify this part accordingly.

# Ex5: Modify the Descriptor Computation
# The function extract_color_descriptor already computes a basic color descriptor.
# For enhancements, modify the extract_color_descriptor function.

# Ex6: (Optional) Modify the Descriptor to a Global Colour Histogram
# This step would involve modifying the extract_color_descriptor to calculate histograms.
# This is placeholder and needs actual implementation if required.

# %%
def calculate_distance(F1, F2):
    dist = np.linalg.norm(F1 - F2)
    return dist

# %%
import random

random_image = random.choice(image_paths)
image_name = random_image.split('/')[-1].split('.')[0]
FEATURES_FOLDER = './python/descriptors/better_descriptors/'
image_feature_path = FEATURES_FOLDER + image_name + '.npy'
image_feature = np.load(image_feature_path, allow_pickle=True)
features_paths = glob.glob(FEATURES_FOLDER + '*.npy', recursive=True)
similarity_list = []
for feature_path in features_paths:
    similarity_dict = {'image_name':'', 'dist':10000}
    name = feature_path.split('/')[-1].split('.')[0]
    F = np.load(feature_path)
    dist = calculate_distance(F, image_feature)
    similarity_dict['image_name'] = name + '.bmp'
    similarity_dict['dist'] = dist
    similarity_list.append(similarity_dict)

sorted_list = sorted(similarity_list, key=lambda dist: dist['dist'])

# %%
import json
# Calculate precision
rgb_to_index = {
    (0, 0, 0): 0,         # void
    (128, 0, 0): 1,       # building
    (0, 128, 0): 2,       # grass
    (128, 128, 0): 3,     # tree
    (0, 0, 128): 4,       # cow
    (128, 0, 128): 5,     # horse
    (0, 128, 128): 6,     # sheep
    (128, 128, 128): 7,   # sky
    (64, 0, 0): 8,        # mountain
    (192, 0, 0): 9,       # aeroplane
    (64, 128, 0): 10,     # water
    (192, 128, 0): 11,    # face
    (64, 0, 128): 12,     # car
    (192, 0, 128): 13,    # bicycle
    (64, 128, 128): 14,   # flower
    (192, 128, 128): 15,  # sign
    (0, 64, 0): 16,       # bird
    (128, 64, 0): 17,     # book
    (0, 192, 0): 18,      # chair
    (128, 64, 128): 19,   # road
    (0, 192, 128): 20,    # cat
    (128, 192, 128): 21,  # dog
    (64, 64, 0): 22,      # body
    (192, 64, 0): 23      # boat
}
index_to_class_name = {
    0: "void",
    1: "building",
    2: "grass",
    3: "tree",
    4: "cow",
    5: "horse",
    6: "sheep",
    7: "sky",
    8: "mountain",
    9: "aeroplane",
    10: "water",
    11: "face",
    12: "car",
    13: "bicycle",
    14: "flower",
    15: "sign",
    16: "bird",
    17: "book",
    18: "chair",
    19: "road",
    20: "cat",
    21: "dog",
    22: "body",
    23: "boat"
}
def get_class_vector(img):
    class_vector = np.zeros(24)
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            pixel_value = tuple(img[i, j])
            pixel_index = rgb_to_index[pixel_value]
            class_vector[pixel_index] += 1
    class_vector = class_vector/class_vector.sum() # normalize class vector
    return class_vector
    
GROUND_TRUTH_FOLDER = './MSRC_ObjCategImageDatabase_v2/GroundTruth/'
LABELS_FOLDER = './MSRC_ObjCategImageDatabase_v2/labels/'
label_image_paths = glob.glob(GROUND_TRUTH_FOLDER + '*.bmp')
classes_dict = {}
for label_image_path in label_image_paths:
    label_dict = {}
    label_image = cv2.imread(label_image_path)
    label_image = cv2.cvtColor(label_image, cv2.COLOR_RGB2BGR)
    name = label_image_path.split('/')[-1].split('.')[0]
    class_vector = get_class_vector(label_image)
    for i in range(len(class_vector)):
        label_dict[index_to_class_name[i]] = class_vector[i]
    with open(LABELS_FOLDER + name + '.json', 'w') as outfile:
        json.dump(label_dict, outfile)

# %%
def calculate_precision_recall_multi(query_class_proportions, retrieved_images):
    # Initialize cumulative proportions for each class
    cumulative_retrieved_proportions = {}
    precision_per_class = {}
    recall_per_class = {}

    # Sum the proportions of each class over all retrieved images
    for image in retrieved_images:
        for class_label, proportion in image.items():
            if class_label in cumulative_retrieved_proportions:
                cumulative_retrieved_proportions[class_label] += proportion
            else:
                cumulative_retrieved_proportions[class_label] = proportion

    # Calculate precision and recall for each class
    for class_label, query_proportion in query_class_proportions.items():
        retrieved_proportion = cumulative_retrieved_proportions.get(class_label, 0)

        # Precision for this class
        precision_per_class[class_label] = min(retrieved_proportion, query_proportion) / max(retrieved_proportion, 1e-6)
        
        # Recall for this class
        recall_per_class[class_label] = min(retrieved_proportion, query_proportion) / query_proportion

    return precision_per_class, recall_per_class

# %%
import matplotlib.pyplot as plt
top_15 = sorted_list[0:16]
f, axarr = plt.subplots(1, 16, figsize=(30, 15)) 

# Left-most image is the query image
i = 0
query_label = {}
search_labels = []
for image_dict in top_15:
    
    label_path = LABELS_FOLDER + image_dict['image_name'].split('.')[0] + '_GT.json'
    with open(label_path) as json_file:
        data = json.load(json_file)
        class_vector = list(data.values())

        if i == 0:
            for j in range(23):
                if class_vector[j] != 0:
                    query_label[index_to_class_name[j]]= class_vector[j]
            # query_label = list(data.values())
        else:
            label_dict = {}
            for j in range(23):
                if class_vector[j] != 0:
                    label_dict[index_to_class_name[j]]= class_vector[j]
            search_labels.append(label_dict)
        # dist = calculate_distance(np.array(query_label), np.array(class_vector)) labels distance

        
        image_path = DATASET_FOLDER + image_dict['image_name']
        img = cv2.imread(image_path)  # Load the image
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        axarr[i].imshow(img)  # Display the image
        axarr[i].axis('off')  # Turn off axis if you don't want the grid lines
        i+=1
plt.show()

# %%
query_label

# %%
precision, recall = calculate_precision_recall_multi(query_label, search_labels)

# %%
# Out:
# {'void': 0.07666153642095222,
#  'grass': 0.0896512692650447,
#  'tree': 0.01565636698824168,
#  'face': 0.006830320609860467,
#  'flower': 0.0,
#  'body': 0.10466510565563147}

# %%
print(precision, recall)
# Out:
# {'void': 0.0358696810036136, 'grass': 0.20508321039418176, 'dog': 1.0} {'void': 1.0, 'grass': 1.0, 'dog': 0.9139290407358738}

# %%
 
img=cv2.drawKeypoints(gray,kp,img)
 
cv2.imwrite('./sift_test.jpg',img)

# %%
kp
# Out:
# < cv2.KeyPoint 0x160535560>

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[74], line 73
#      71 label_image = cv2.cvtColor(label_image, cv2.COLOR_RGB2BGR)
#      72 name = label_image_path.split('/')[-1].split('.')[0]
# ---> 73 class_vector = get_class_vector(label_image)
#      74 for i in range(len(class_vector)):
#      75     label_dict[index_to_class_name[i]] = class_vector[i]
#
# Cell In[74], line 61, in get_class_vector(img)
#      59         pixel_value = tuple(img[i, j])
#      60         pixel_index = rgb_to_index[pixel_value]
# ---> 61         class_vector[pixel_index] += 1
#      62 class_vector = class_vector/class_vector.sum() # normalize class vector
#      63 return class_vector
#
# KeyboardInterrupt:

# %%
sorted_list
# Out:
# [{'image_name': '19_10_s.bmp', 'dist': 0.0},
#  {'image_name': '3_7_s.bmp', 'dist': 15573.051146130612},
#  {'image_name': '16_26_s.bmp', 'dist': 15795.049604227268},
#  {'image_name': '9_17_s.bmp', 'dist': 17251.64108135803},
#  {'image_name': '17_3_s.bmp', 'dist': 17591.441555483736},
#  {'image_name': '14_5_s.bmp', 'dist': 18149.824351767154},
#  {'image_name': '12_30_s.bmp', 'dist': 18827.548326853394},
#  {'image_name': '14_16_s.bmp', 'dist': 19259.691482471884},
#  {'image_name': '19_21_s.bmp', 'dist': 19316.031942404734},
#  {'image_name': '16_27_s.bmp', 'dist': 20038.033336632616},
#  {'image_name': '6_29_s.bmp', 'dist': 20551.834516655686},
#  {'image_name': '9_28_s.bmp', 'dist': 20906.462206695804},
#  {'image_name': '11_26_s.bmp', 'dist': 20911.152383357545},
#  {'image_name': '4_24_s.bmp', 'dist': 21685.30769899288},
#  {'image_name': '6_2_s.bmp', 'dist': 21855.018142294004},
#  {'image_name': '18_24_s.bmp', 'dist': 22102.10053365969},
#  {'image_name': '12_12_s.bmp', 'dist': 22116.21875457014},
#  {'image_name': '14_11_s.bmp', 'dist': 22245.326790137293},
#  {'image_name': '8_6_s.bmp', 'dist': 22500.28733149868},
#  {'image_name': '12_19_s.bmp', 'dist': 22794.61822448448},
#  {'image_name': '19_7_s.bmp', 'dist': 23285.42728832778},
#  {'image_name': '1_5_s.bmp', 'dist': 23452.013644887724},
#  {'image_name': '9_22_s.bmp', 'dist': 23849.364519835744},
#  {'image_name': '4_27_s.bmp', 'dist': 23995.795340017383},
#  {'image_name': '16_22_s.bmp', 'dist': 24089.297914219085},
#  {'image_name': '15_11_s.bmp', 'dist': 24107.16308485924},
#  {'image_name': '14_7_s.bmp', 'dist': 24376.924211228947},
#  {'image_name': '19_24_s.bmp', 'dist': 24457.995338947956},
#  {'image_name': '9_4_s.bmp', 'dist': 24509.80061118409},
#  {'image_name': '9_8_s.bmp', 'dist': 24584.924405008856},
#  {'image_name': '3_2_s.bmp', 'dist': 24642.193124801208},
#  {'image_name': '16_2_s.bmp', 'dist': 24670.85701794731},
#  {'image_name': '8_24_s.bmp', 'dist': 24761.82864814309},
#  {'image_name': '19_22_s.bmp', 'dist': 24851.926042059597},
#  {'image_name': '16_20_s.bmp', 'dist': 24864.460380229448},
#  {'image_name': '18_23_s.bmp', 'dist': 25033.63597242718},
#  {'image_name': '14_24_s.bmp', 'dist': 25130.40473211683},
#  {'image_name': '10_26_s.bmp', 'dist': 25151.788763425953},
#  {'image_name': '1_13_s.bmp', 'dist': 25207.78931203607},
#  {'image_name': '8_27_s.bmp', 'dist': 25283.573046545458},
#  {'image_name': '8_28_s.bmp', 'dist': 25305.05253896937},
#  {'image_name': '4_8_s.bmp', 'dist': 25373.198142922385},
#  {'image_name': '20_14_s.bmp', 'dist': 25439.707584797434},
#  {'image_name': '9_30_s.bmp', 'dist': 25609.570047152294},
#  {'image_name': '8_2_s.bmp', 'dist': 25678.44816183408},
#  {'image_name': '12_20_s.bmp', 'dist': 25684.888086187955},
#  {'image_name': '19_3_s.bmp', 'dist': 25759.414628442162},
#  {'image_name': '8_23_s.bmp', 'dist': 25970.706613413506},
#  {'image_name': '16_8_s.bmp', 'dist': 26141.598612173664},
#  {'image_name': '7_24_s.bmp', 'dist': 26287.529096512666},
#  {'image_name': '5_1_s.bmp', 'dist': 26313.47578713234},
#  {'image_name': '19_4_s.bmp', 'dist': 26398.481054787982},
#  {'image_name': '3_15_s.bmp', 'dist': 26452.462002618962},
#  {'image_name': '19_8_s.bmp', 'dist': 26517.778489157045},
#  {'image_name': '20_11_s.bmp', 'dist': 26526.180803123545},
#  {'image_name': '9_6_s.bmp', 'dist': 26575.782396761155},
#  {'image_name': '2_4_s.bmp', 'dist': 26613.922221273588},
#  {'image_name': '2_3_s.bmp', 'dist': 26773.098065035356},
#  {'image_name': '14_22_s.bmp', 'dist': 27003.59864906898},
#  {'image_name': '9_29_s.bmp', 'dist': 27033.72556641056},
#  {'image_name': '3_22_s.bmp', 'dist': 27645.396253264305},
#  {'image_name': '7_3_s.bmp', 'dist': 27649.964990936245},
#  {'image_name': '17_26_s.bmp', 'dist': 27658.353421706073},
#  {'image_name': '8_26_s.bmp', 'dist': 27697.55750964334},
#  {'image_name': '12_10_s.bmp', 'dist': 27961.472564941927},
#  {'image_name': '5_30_s.bmp', 'dist': 27972.98049904586},
#  {'image_name': '1_6_s.bmp', 'dist': 28021.027033283415},
#  {'image_name': '18_2_s.bmp', 'dist': 28038.62664254439},
#  {'image_name': '8_16_s.bmp', 'dist': 28083.304542022826},
#  {'image_name': '1_4_s.bmp', 'dist': 28115.31049090513},
#  {'image_name': '5_5_s.bmp', 'dist': 28173.72392851183},
#  {'image_name': '16_18_s.bmp', 'dist': 28235.939403533223},
#  {'image_name': '6_4_s.bmp', 'dist': 28505.040922615775},
#  {'image_name': '11_29_s.bmp', 'dist': 28674.723852201263},
#  {'image_name': '2_2_s.bmp', 'dist': 28676.451558726716},
#  {'image_name': '14_23_s.bmp', 'dist': 28810.13082233401},
#  {'image_name': '5_24_s.bmp', 'dist': 28980.10821235835},
#  {'image_name': '8_5_s.bmp', 'dist': 29078.523552615254},
#  {'image_name': '3_5_s.bmp', 'dist': 29298.898204540048},
#  {'image_name': '14_12_s.bmp', 'dist': 29327.63386296276},
#  {'image_name': '14_4_s.bmp', 'dist': 29330.395292256122},
#  {'image_name': '15_5_s.bmp', 'dist': 29422.224253105},
#  {'image_name': '12_21_s.bmp', 'dist': 29731.61633682232},
#  {'image_name': '19_26_s.bmp', 'dist': 29779.300797701748},
#  {'image_name': '2_15_s.bmp', 'dist': 29974.5161095221},
#  {'image_name': '8_10_s.bmp', 'dist': 30056.91158452578},
#  {'image_name': '8_17_s.bmp', 'dist': 30065.910862636443},
#  {'image_name': '7_4_s.bmp', 'dist': 30084.031212588514},
#  {'image_name': '5_9_s.bmp', 'dist': 30141.68960094971},
#  {'image_name': '18_28_s.bmp', 'dist': 30173.133877673365},
#  {'image_name': '14_19_s.bmp', 'dist': 30194.493935153143},
#  {'image_name': '7_12_s.bmp', 'dist': 30318.802285050773},
#  {'image_name': '7_30_s.bmp', 'dist': 30331.65640053309},
#  {'image_name': '13_3_s.bmp', 'dist': 30374.353984899826},
#  {'image_name': '15_4_s.bmp', 'dist': 30399.169001800034},
#  {'image_name': '7_2_s.bmp', 'dist': 30415.347967761278},
#  {'image_name': '14_27_s.bmp', 'dist': 30610.719396969424},
#  {'image_name': '7_20_s.bmp', 'dist': 30623.885057255553},
#  {'image_name': '9_7_s.bmp', 'dist': 30650.976656543917},
#  {'image_name': '2_10_s.bmp', 'dist': 30764.60765230072},
#  {'image_name': '7_18_s.bmp', 'dist': 30766.91407990083},
#  {'image_name': '2_5_s.bmp', 'dist': 30826.871524694165},
#  {'image_name': '5_7_s.bmp', 'dist': 30867.985065436325},
#  {'image_name': '15_10_s.bmp', 'dist': 30990.24978924823},
#  {'image_name': '4_6_s.bmp', 'dist': 30990.82422266307},
#  {'image_name': '14_17_s.bmp', 'dist': 31091.733885391466},
#  {'image_name': '9_18_s.bmp', 'dist': 31204.967841675465},
#  {'image_name': '4_11_s.bmp', 'dist': 31221.659981493616},
#  {'image_name': '12_9_s.bmp', 'dist': 31352.494956542134},
#  {'image_name': '7_17_s.bmp', 'dist': 31443.35570514063},
#  {'image_name': '16_29_s.bmp', 'dist': 31516.850699268794},
#  {'image_name': '3_30_s.bmp', 'dist': 31537.9187011445},
#  {'image_name': '15_24_s.bmp', 'dist': 31616.38426512431},
#  {'image_name': '3_12_s.bmp', 'dist': 31640.8660437732},
#  {'image_name': '17_20_s.bmp', 'dist': 31685.05019721446},
#  {'image_name': '17_7_s.bmp', 'dist': 31760.292001176564},
#  {'image_name': '13_17_s.bmp', 'dist': 31990.996264574194},
#  {'image_name': '7_27_s.bmp', 'dist': 32002.61501815125},
#  {'image_name': '9_9_s.bmp', 'dist': 32062.663987884724},
#  {'image_name': '1_23_s.bmp', 'dist': 32087.180835966254},
#  {'image_name': '15_23_s.bmp', 'dist': 32146.28336215557},
#  {'image_name': '17_16_s.bmp', 'dist': 32200.674806593728},
#  {'image_name': '10_4_s.bmp', 'dist': 32204.717480518284},
#  {'image_name': '18_1_s.bmp', 'dist': 32225.666633911547},
#  {'image_name': '9_15_s.bmp', 'dist': 32309.846858194793},
#  {'image_name': '1_27_s.bmp', 'dist': 32309.846858194793},
#  {'image_name': '6_10_s.bmp', 'dist': 32392.476935239145},
#  {'image_name': '1_22_s.bmp', 'dist': 32620.107633176198},
#  {'image_name': '12_11_s.bmp', 'dist': 32675.201912153505},
#  {'image_name': '14_8_s.bmp', 'dist': 32722.964474509336},
#  {'image_name': '7_15_s.bmp', 'dist': 32770.0016478486},
#  {'image_name': '6_26_s.bmp', 'dist': 32793.02093433906},
#  {'image_name': '1_18_s.bmp', 'dist': 32831.79328029464},
#  {'image_name': '1_15_s.bmp', 'dist': 32838.09330640255},
#  {'image_name': '12_24_s.bmp', 'dist': 32846.670120424686},
#  {'image_name': '10_31_s.bmp', 'dist': 32868.58445385198},
#  {'image_name': '1_2_s.bmp', 'dist': 32966.53888414736},
#  {'image_name': '4_29_s.bmp', 'dist': 33085.23797707975},
#  {'image_name': '2_22_s.bmp', 'dist': 33085.38299612081},
#  {'image_name': '4_19_s.bmp', 'dist': 33125.79025472449},
#  {'image_name': '4_9_s.bmp', 'dist': 33296.41551278456},
#  {'image_name': '6_22_s.bmp', 'dist': 33308.22769226847},
#  {'image_name': '6_27_s.bmp', 'dist': 33407.44872030787},
#  {'image_name': '14_29_s.bmp', 'dist': 33520.14364527694},
#  {'image_name': '8_15_s.bmp', 'dist': 33523.65454421698},
#  {'image_name': '9_26_s.bmp', 'dist': 33570.969005973006},
#  {'image_name': '19_30_s.bmp', 'dist': 33607.73175922469},
#  {'image_name': '19_5_s.bmp', 'dist': 33623.918956599926},
#  {'image_name': '6_20_s.bmp', 'dist': 33655.13176322446},
#  {'image_name': '2_23_s.bmp', 'dist': 33707.11016981432},
#  {'image_name': '4_12_s.bmp', 'dist': 33756.66657121227},
#  {'image_name': '19_17_s.bmp', 'dist': 33933.32067452285},
#  {'image_name': '1_1_s.bmp', 'dist': 33991.35801935545},
#  {'image_name': '1_10_s.bmp', 'dist': 34006.09648283672},
#  {'image_name': '15_13_s.bmp', 'dist': 34108.49773883336},
#  {'image_name': '12_2_s.bmp', 'dist': 34136.79337606273},
#  {'image_name': '19_29_s.bmp', 'dist': 34145.026372811604},
#  {'image_name': '2_12_s.bmp', 'dist': 34302.68695015013},
#  {'image_name': '6_1_s.bmp', 'dist': 34335.269825647214},
#  {'image_name': '11_28_s.bmp', 'dist': 34398.239402620595},
#  {'image_name': '13_9_s.bmp', 'dist': 34533.73507166579},
#  {'image_name': '3_8_s.bmp', 'dist': 34541.68252995213},
#  {'image_name': '18_8_s.bmp', 'dist': 34696.54429478532},
#  {'image_name': '1_19_s.bmp', 'dist': 34773.25270951798},
#  {'image_name': '16_21_s.bmp', 'dist': 34782.82889587907},
#  {'image_name': '8_13_s.bmp', 'dist': 34782.87748303754},
#  {'image_name': '13_18_s.bmp', 'dist': 34900.64179925636},
#  {'image_name': '6_23_s.bmp', 'dist': 34906.005643728415},
#  {'image_name': '6_6_s.bmp', 'dist': 35233.59249352811},
#  {'image_name': '11_22_s.bmp', 'dist': 35298.02235253414},
#  {'image_name': '3_16_s.bmp', 'dist': 35304.87113699751},
#  {'image_name': '18_9_s.bmp', 'dist': 35310.624066985845},
#  {'image_name': '4_26_s.bmp', 'dist': 35336.30764525349},
#  {'image_name': '7_11_s.bmp', 'dist': 35356.57339166226},
#  {'image_name': '14_6_s.bmp', 'dist': 35357.51371349519},
#  {'image_name': '17_28_s.bmp', 'dist': 35358.72115900121},
#  {'image_name': '14_18_s.bmp', 'dist': 35366.60031724848},
#  {'image_name': '8_8_s.bmp', 'dist': 35440.49026184598},
#  {'image_name': '4_17_s.bmp', 'dist': 35453.58672969492},
#  {'image_name': '19_25_s.bmp', 'dist': 35455.9475123709},
#  {'image_name': '12_29_s.bmp', 'dist': 35504.5225006618},
#  {'image_name': '4_28_s.bmp', 'dist': 35604.90904355746},
#  {'image_name': '8_11_s.bmp', 'dist': 35625.43330262805},
#  {'image_name': '10_18_s.bmp', 'dist': 35731.59042080271},
#  {'image_name': '12_23_s.bmp', 'dist': 35775.27461809343},
#  {'image_name': '13_7_s.bmp', 'dist': 35782.737793522734},
#  {'image_name': '4_16_s.bmp', 'dist': 35818.24495979668},
#  {'image_name': '18_10_s.bmp', 'dist': 35828.35251584979},
#  {'image_name': '2_1_s.bmp', 'dist': 35830.82346248827},
#  {'image_name': '17_17_s.bmp', 'dist': 35872.425371028374},
#  {'image_name': '7_29_s.bmp', 'dist': 35900.45737870201},
#  {'image_name': '16_9_s.bmp', 'dist': 35921.380652753316},
#  {'image_name': '18_18_s.bmp', 'dist': 35996.3264514589},
#  {'image_name': '15_21_s.bmp', 'dist': 36000.58230084619},
#  {'image_name': '12_25_s.bmp', 'dist': 36021.134462978815},
#  {'image_name': '17_8_s.bmp', 'dist': 36057.62246737852},
#  {'image_name': '7_25_s.bmp', 'dist': 36105.654017064975},
#  {'image_name': '17_29_s.bmp', 'dist': 36159.48442663418},
#  {'image_name': '4_15_s.bmp', 'dist': 36164.466870119904},
#  {'image_name': '18_22_s.bmp', 'dist': 36176.76596933452},
#  {'image_name': '12_34_s.bmp', 'dist': 36177.74387658799},
#  {'image_name': '19_9_s.bmp', 'dist': 36194.81788875308},
#  {'image_name': '10_21_s.bmp', 'dist': 36344.27938479452},
#  {'image_name': '12_32_s.bmp', 'dist': 36391.979913162184},
#  {'image_name': '4_10_s.bmp', 'dist': 36430.07526755881},
#  {'image_name': '15_3_s.bmp', 'dist': 36510.149246476656},
#  {'image_name': '7_1_s.bmp', 'dist': 36548.80569868186},
#  {'image_name': '19_1_s.bmp', 'dist': 36564.03169783114},
#  {'image_name': '19_20_s.bmp', 'dist': 36624.94486002675},
#  {'image_name': '7_19_s.bmp', 'dist': 36646.870807751104},
#  {'image_name': '16_1_s.bmp', 'dist': 36679.1895493889},
#  {'image_name': '3_13_s.bmp', 'dist': 36715.78467090143},
#  {'image_name': '3_24_s.bmp', 'dist': 36732.605624975746},
#  {'image_name': '1_8_s.bmp', 'dist': 36732.76929391521},
#  {'image_name': '1_29_s.bmp', 'dist': 36787.3153682081},
#  {'image_name': '3_9_s.bmp', 'dist': 36793.32654164339},
#  {'image_name': '17_18_s.bmp', 'dist': 36840.206351213616},
#  {'image_name': '3_21_s.bmp', 'dist': 36871.376594860136},
#  {'image_name': '14_28_s.bmp', 'dist': 36873.46349341217},
#  {'image_name': '4_14_s.bmp', 'dist': 36963.16101201303},
#  {'image_name': '17_30_s.bmp', 'dist': 37012.29320104335},
#  {'image_name': '5_22_s.bmp', 'dist': 37202.056072211926},
#  {'image_name': '5_12_s.bmp', 'dist': 37223.16880653768},
#  {'image_name': '9_5_s.bmp', 'dist': 37329.15220039159},
#  {'image_name': '9_11_s.bmp', 'dist': 37334.52637974667},
#  {'image_name': '1_26_s.bmp', 'dist': 37376.78158964466},
#  {'image_name': '9_10_s.bmp', 'dist': 37376.78158964466},
#  {'image_name': '18_20_s.bmp', 'dist': 37421.124221487524},
#  {'image_name': '10_16_s.bmp', 'dist': 37431.95511858818},
#  {'image_name': '10_1_s.bmp', 'dist': 37492.731615607845},
#  {'image_name': '1_25_s.bmp', 'dist': 37596.38341649366},
#  {'image_name': '17_15_s.bmp', 'dist': 37649.541776760045},
#  {'image_name': '6_3_s.bmp', 'dist': 37670.91806685895},
#  {'image_name': '6_14_s.bmp', 'dist': 37826.37524267955},
#  {'image_name': '2_17_s.bmp', 'dist': 37971.774675408575},
#  {'image_name': '15_19_s.bmp', 'dist': 38053.54824454613},
#  {'image_name': '5_18_s.bmp', 'dist': 38073.54761510937},
#  {'image_name': '14_15_s.bmp', 'dist': 38101.98703479912},
#  {'image_name': '17_4_s.bmp', 'dist': 38115.68813493992},
#  {'image_name': '16_10_s.bmp', 'dist': 38170.48223431294},
#  {'image_name': '16_5_s.bmp', 'dist': 38174.58591785902},
#  {'image_name': '14_3_s.bmp', 'dist': 38228.48100565859},
#  {'image_name': '6_25_s.bmp', 'dist': 38246.25801303965},
#  {'image_name': '20_12_s.bmp', 'dist': 38250.82216109871},
#  {'image_name': '3_1_s.bmp', 'dist': 38270.990841628336},
#  {'image_name': '17_2_s.bmp', 'dist': 38343.04578407928},
#  {'image_name': '5_4_s.bmp', 'dist': 38361.638207980635},
#  {'image_name': '9_13_s.bmp', 'dist': 38394.647022729616},
#  {'image_name': '6_17_s.bmp', 'dist': 38400.76066954924},
#  {'image_name': '18_11_s.bmp', 'dist': 38425.012739100035},
#  {'image_name': '6_7_s.bmp', 'dist': 38448.87194704157},
#  {'image_name': '19_6_s.bmp', 'dist': 38456.49079154259},
#  {'image_name': '8_1_s.bmp', 'dist': 38475.85650768544},
#  {'image_name': '13_15_s.bmp', 'dist': 38486.81852270982},
#  {'image_name': '12_1_s.bmp', 'dist': 38495.07794510877},
#  {'image_name': '20_18_s.bmp', 'dist': 38518.22225908148},
#  {'image_name': '7_10_s.bmp', 'dist': 38569.976458380166},
#  {'image_name': '9_19_s.bmp', 'dist': 38722.05908781195},
#  {'image_name': '7_21_s.bmp', 'dist': 38730.42044698198},
#  {'image_name': '1_9_s.bmp', 'dist': 38785.40576041457},
#  {'image_name': '6_19_s.bmp', 'dist': 38809.248614215656},
#  {'image_name': '6_8_s.bmp', 'dist': 39040.15002532649},
#  {'image_name': '6_18_s.bmp', 'dist': 39302.636654555376},
#  {'image_name': '6_15_s.bmp', 'dist': 39334.754581667345},
#  {'image_name': '15_9_s.bmp', 'dist': 39363.953307563},
#  {'image_name': '8_4_s.bmp', 'dist': 39519.60976527982},
#  {'image_name': '15_20_s.bmp', 'dist': 39547.83114154302},
#  {'image_name': '20_13_s.bmp', 'dist': 39586.37417091896},
#  {'image_name': '5_10_s.bmp', 'dist': 39657.521707741646},
#  {'image_name': '15_6_s.bmp', 'dist': 39702.34690795999},
#  {'image_name': '8_7_s.bmp', 'dist': 39818.05407098644},
#  {'image_name': '11_10_s.bmp', 'dist': 39846.94753679383},
#  {'image_name': '7_16_s.bmp', 'dist': 39880.670556047575},
#  {'image_name': '3_29_s.bmp', 'dist': 39883.25127168045},
#  {'image_name': '19_18_s.bmp', 'dist': 39953.80913004416},
#  {'image_name': '8_3_s.bmp', 'dist': 39978.43156002997},
#  {'image_name': '17_13_s.bmp', 'dist': 40055.314853337506},
#  {'image_name': '5_6_s.bmp', 'dist': 40144.048774382485},
#  {'image_name': '19_13_s.bmp', 'dist': 40214.858870820375},
#  {'image_name': '15_7_s.bmp', 'dist': 40238.603106966824},
#  {'image_name': '20_4_s.bmp', 'dist': 40291.57274170369},
#  {'image_name': '6_11_s.bmp', 'dist': 40310.07142142023},
#  {'image_name': '5_3_s.bmp', 'dist': 40346.47186557952},
#  {'image_name': '14_13_s.bmp', 'dist': 40355.19173538889},
#  {'image_name': '10_3_s.bmp', 'dist': 40356.228119089625},
#  {'image_name': '2_11_s.bmp', 'dist': 40383.81465389321},
#  {'image_name': '8_30_s.bmp', 'dist': 40393.287858256845},
#  {'image_name': '2_8_s.bmp', 'dist': 40397.98910837023},
#  {'image_name': '8_25_s.bmp', 'dist': 40459.29361716539},
#  {'image_name': '19_27_s.bmp', 'dist': 40490.29851705221},
#  {'image_name': '14_2_s.bmp', 'dist': 40515.837471290164},
#  {'image_name': '17_1_s.bmp', 'dist': 40577.83439268291},
#  {'image_name': '3_19_s.bmp', 'dist': 40619.94556864891},
#  {'image_name': '18_5_s.bmp', 'dist': 40689.85278911685},
#  {'image_name': '9_12_s.bmp', 'dist': 40748.51884424758},
#  {'image_name': '7_28_s.bmp', 'dist': 40811.14404179329},
#  {'image_name': '5_15_s.bmp', 'dist': 40827.34392536453},
#  {'image_name': '13_8_s.bmp', 'dist': 40846.24545781411},
#  {'image_name': '19_12_s.bmp', 'dist': 40926.73759292329},
#  {'image_name': '7_5_s.bmp', 'dist': 40976.93736725574},
#  {'image_name': '1_30_s.bmp', 'dist': 40986.36963674631},
#  {'image_name': '2_27_s.bmp', 'dist': 40994.152583020914},
#  {'image_name': '1_7_s.bmp', 'dist': 41002.21545233867},
#  {'image_name': '20_19_s.bmp', 'dist': 41037.559259780544},
#  {'image_name': '7_8_s.bmp', 'dist': 41170.10412908862},
#  {'image_name': '2_28_s.bmp', 'dist': 41200.23849445534},
#  {'image_name': '2_6_s.bmp', 'dist': 41300.40162032326},
#  {'image_name': '12_33_s.bmp', 'dist': 41392.57952821979},
#  {'image_name': '18_21_s.bmp', 'dist': 41514.957280479044},
#  {'image_name': '5_21_s.bmp', 'dist': 41649.74470509993},
#  {'image_name': '6_16_s.bmp', 'dist': 41698.31224402254},
#  {'image_name': '3_3_s.bmp', 'dist': 41726.93180668811},
#  {'image_name': '17_5_s.bmp', 'dist': 42064.3607107014},
#  {'image_name': '8_19_s.bmp', 'dist': 42081.145326618665},
#  {'image_name': '4_30_s.bmp', 'dist': 42115.48109662289},
#  {'image_name': '8_9_s.bmp', 'dist': 42294.44497803465},
#  {'image_name': '4_25_s.bmp', 'dist': 42334.527043537404},
#  {'image_name': '5_28_s.bmp', 'dist': 42367.15895596494},
#  {'image_name': '1_21_s.bmp', 'dist': 42384.352891131886},
#  {'image_name': '3_25_s.bmp', 'dist': 42395.12566321746},
#  {'image_name': '12_27_s.bmp', 'dist': 42534.318638012766},
#  {'image_name': '6_30_s.bmp', 'dist': 42560.39341923427},
#  {'image_name': '20_3_s.bmp', 'dist': 42567.57839013162},
#  {'image_name': '1_28_s.bmp', 'dist': 42584.04821056824},
#  {'image_name': '8_12_s.bmp', 'dist': 42594.694974843995},
#  {'image_name': '3_27_s.bmp', 'dist': 42730.59491745932},
#  {'image_name': '7_7_s.bmp', 'dist': 42754.574959880025},
#  {'image_name': '12_13_s.bmp', 'dist': 42766.644993499314},
#  {'image_name': '18_4_s.bmp', 'dist': 42818.36045436584},
#  {'image_name': '16_30_s.bmp', 'dist': 42839.9822829095},
#  {'image_name': '14_20_s.bmp', 'dist': 43014.419652019016},
#  {'image_name': '20_15_s.bmp', 'dist': 43056.922207700816},
#  {'image_name': '3_18_s.bmp', 'dist': 43078.00998189215},
#  {'image_name': '17_27_s.bmp', 'dist': 43100.875861170156},
#  {'image_name': '18_17_s.bmp', 'dist': 43102.12319596333},
#  {'image_name': '18_16_s.bmp', 'dist': 43144.33948967118},
#  {'image_name': '20_16_s.bmp', 'dist': 43157.356823605405},
#  {'image_name': '18_15_s.bmp', 'dist': 43261.13736368936},
#  {'image_name': '16_4_s.bmp', 'dist': 43318.79211150745},
#  {'image_name': '11_24_s.bmp', 'dist': 43341.899958354385},
#  {'image_name': '19_28_s.bmp', 'dist': 43343.89853255011},
#  {'image_name': '1_11_s.bmp', 'dist': 43446.66175898903},
#  {'image_name': '17_23_s.bmp', 'dist': 43597.30932064501},
#  {'image_name': '8_22_s.bmp', 'dist': 43653.129441083605},
#  {'image_name': '13_14_s.bmp', 'dist': 43681.97541320676},
#  {'image_name': '12_5_s.bmp', 'dist': 43720.794434685195},
#  {'image_name': '3_14_s.bmp', 'dist': 43721.35283817279},
#  {'image_name': '18_7_s.bmp', 'dist': 43722.25989127278},
#  {'image_name': '10_13_s.bmp', 'dist': 43894.61935135103},
#  {'image_name': '20_8_s.bmp', 'dist': 43925.7294760144},
#  {'image_name': '4_7_s.bmp', 'dist': 43956.66839058665},
#  {'image_name': '9_21_s.bmp', 'dist': 44112.15614771058},
#  {'image_name': '4_20_s.bmp', 'dist': 44166.380041837256},
#  {'image_name': '2_18_s.bmp', 'dist': 44220.94297954308},
#  {'image_name': '19_16_s.bmp', 'dist': 44231.09826807379},
#  {'image_name': '11_12_s.bmp', 'dist': 44239.455398998754},
#  {'image_name': '11_3_s.bmp', 'dist': 44258.58820613238},
#  {'image_name': '12_4_s.bmp', 'dist': 44317.97283270073},
#  {'image_name': '6_12_s.bmp', 'dist': 44391.87297242593},
#  {'image_name': '13_10_s.bmp', 'dist': 44439.37632325638},
#  {'image_name': '17_12_s.bmp', 'dist': 44440.818714330635},
#  {'image_name': '6_28_s.bmp', 'dist': 44501.00113480594},
#  {'image_name': '5_11_s.bmp', 'dist': 44521.35653818289},
#  {'image_name': '8_14_s.bmp', 'dist': 44525.33072308391},
#  {'image_name': '13_12_s.bmp', 'dist': 44553.281719756626},
#  {'image_name': '2_9_s.bmp', 'dist': 44604.688565216995},
#  {'image_name': '10_32_s.bmp', 'dist': 44625.760497721494},
#  {'image_name': '7_6_s.bmp', 'dist': 44647.907700137526},
#  {'image_name': '5_2_s.bmp', 'dist': 44658.468155546936},
#  {'image_name': '1_3_s.bmp', 'dist': 44707.57886533334},
#  {'image_name': '10_28_s.bmp', 'dist': 44707.75089400047},
#  {'image_name': '13_29_s.bmp', 'dist': 44713.18387232115},
#  {'image_name': '9_27_s.bmp', 'dist': 44756.681288942775},
#  {'image_name': '10_27_s.bmp', 'dist': 44786.35129143699},
#  {'image_name': '1_20_s.bmp', 'dist': 44845.88583136696},
#  {'image_name': '7_13_s.bmp', 'dist': 44977.2831549439},
#  {'image_name': '13_5_s.bmp', 'dist': 44989.44442866571},
#  {'image_name': '3_23_s.bmp', 'dist': 45191.792285768},
#  {'image_name': '7_23_s.bmp', 'dist': 45289.924155379194},
#  {'image_name': '13_25_s.bmp', 'dist': 45311.7724438142},
#  {'image_name': '3_11_s.bmp', 'dist': 45341.588569435895},
#  {'image_name': '5_16_s.bmp', 'dist': 45395.608157618066},
#  {'image_name': '20_21_s.bmp', 'dist': 45395.72402770992},
#  {'image_name': '10_22_s.bmp', 'dist': 45446.92108383141},
#  {'image_name': '17_24_s.bmp', 'dist': 45450.93382979056},
#  {'image_name': '13_23_s.bmp', 'dist': 45466.9639408659},
#  {'image_name': '3_28_s.bmp', 'dist': 45549.189015832104},
#  {'image_name': '4_13_s.bmp', 'dist': 45563.672152274994},
#  {'image_name': '11_15_s.bmp', 'dist': 45615.03855089898},
#  {'image_name': '4_23_s.bmp', 'dist': 45645.56445044798},
#  {'image_name': '16_28_s.bmp', 'dist': 45682.4630465565},
#  {'image_name': '7_9_s.bmp', 'dist': 45688.30403943661},
#  {'image_name': '12_31_s.bmp', 'dist': 45745.5064241287},
#  {'image_name': '9_14_s.bmp', 'dist': 46028.9789589124},
#  {'image_name': '7_14_s.bmp', 'dist': 46066.2935344271},
#  {'image_name': '17_19_s.bmp', 'dist': 46079.09315513924},
#  {'image_name': '14_1_s.bmp', 'dist': 46147.05628748165},
#  {'image_name': '17_10_s.bmp', 'dist': 46162.71930898352},
#  {'image_name': '9_3_s.bmp', 'dist': 46232.349605011426},
#  {'image_name': '18_14_s.bmp', 'dist': 46247.45268660751},
#  {'image_name': '18_19_s.bmp', 'dist': 46416.94714218073},
#  {'image_name': '20_7_s.bmp', 'dist': 46458.08993060305},
#  {'image_name': '11_23_s.bmp', 'dist': 46563.14010029822},
#  {'image_name': '8_18_s.bmp', 'dist': 46773.14135270369},
#  {'image_name': '15_18_s.bmp', 'dist': 46925.407297113576},
#  {'image_name': '16_13_s.bmp', 'dist': 46926.38848238803},
#  {'image_name': '16_6_s.bmp', 'dist': 47155.22656079599},
#  {'image_name': '9_2_s.bmp', 'dist': 47174.79644895143},
#  {'image_name': '8_21_s.bmp', 'dist': 47340.7578731055},
#  {'image_name': '15_1_s.bmp', 'dist': 47416.33699475319},
#  {'image_name': '10_5_s.bmp', 'dist': 47418.89735116159},
#  {'image_name': '11_8_s.bmp', 'dist': 47432.259866044755},
#  {'image_name': '8_20_s.bmp', 'dist': 47490.649121695526},
#  {'image_name': '2_20_s.bmp', 'dist': 47583.51996227265},
#  {'image_name': '3_26_s.bmp', 'dist': 47697.64512006856},
#  {'image_name': '6_24_s.bmp', 'dist': 47722.48327570559},
#  {'image_name': '18_27_s.bmp', 'dist': 47847.66194914857},
#  {'image_name': '4_21_s.bmp', 'dist': 48042.27196958945},
#  {'image_name': '17_9_s.bmp', 'dist': 48123.561297975444},
#  {'image_name': '11_7_s.bmp', 'dist': 48153.20352790663},
#  {'image_name': '10_14_s.bmp', 'dist': 48174.12847161846},
#  {'image_name': '2_26_s.bmp', 'dist': 48222.6978714381},
#  {'image_name': '19_14_s.bmp', 'dist': 48337.36457441593},
#  {'image_name': '5_14_s.bmp', 'dist': 48370.77446144521},
#  {'image_name': '13_20_s.bmp', 'dist': 48390.33630798612},
#  {'image_name': '16_19_s.bmp', 'dist': 48718.79922576089},
#  {'image_name': '3_10_s.bmp', 'dist': 48729.23313576769},
#  {'image_name': '14_21_s.bmp', 'dist': 48839.640580168074},
#  {'image_name': '19_11_s.bmp', 'dist': 48916.82972147725},
#  {'image_name': '19_23_s.bmp', 'dist': 49085.616263830285},
#  {'image_name': '19_2_s.bmp', 'dist': 49149.67654013605},
#  {'image_name': '3_20_s.bmp', 'dist': 49170.7426220105},
#  {'image_name': '8_29_s.bmp', 'dist': 49257.0208396732},
#  {'image_name': '15_14_s.bmp', 'dist': 49262.252831148515},
#  {'image_name': '15_8_s.bmp', 'dist': 49302.71185239206},
#  {'image_name': '12_3_s.bmp', 'dist': 49399.59250844079},
#  {'image_name': '13_28_s.bmp', 'dist': 49429.35662134396},
#  {'image_name': '14_9_s.bmp', 'dist': 49484.92424971468},
#  {'image_name': '7_22_s.bmp', 'dist': 49598.70589037581},
#  {'image_name': '11_30_s.bmp', 'dist': 49737.328577236636},
#  {'image_name': '5_13_s.bmp', 'dist': 49746.401196468476},
#  {'image_name': '13_24_s.bmp', 'dist': 49766.23913859676},
#  {'image_name': '9_23_s.bmp', 'dist': 49775.25638306647},
#  {'image_name': '13_27_s.bmp', 'dist': 49886.11377928732},
#  {'image_name': '9_24_s.bmp', 'dist': 49922.455869077596},
#  {'image_name': '13_26_s.bmp', 'dist': 49948.149415168526},
#  {'image_name': '4_22_s.bmp', 'dist': 50067.68229107475},
#  {'image_name': '13_11_s.bmp', 'dist': 50073.03148402341},
#  {'image_name': '14_10_s.bmp', 'dist': 50077.02974418511},
#  {'image_name': '4_2_s.bmp', 'dist': 50114.25643467136},
#  {'image_name': '10_30_s.bmp', 'dist': 50239.85973308445},
#  {'image_name': '13_16_s.bmp', 'dist': 50253.802284006335},
#  {'image_name': '16_7_s.bmp', 'dist': 50344.477115171234},
#  {'image_name': '17_11_s.bmp', 'dist': 50486.05280669108},
#  {'image_name': '4_4_s.bmp', 'dist': 50598.63174039393},
#  {'image_name': '16_14_s.bmp', 'dist': 50611.01063997833},
#  {'image_name': '13_19_s.bmp', 'dist': 50749.52374160766},
#  {'image_name': '18_6_s.bmp', 'dist': 50797.91995741558},
#  {'image_name': '2_24_s.bmp', 'dist': 50836.75945612584},
#  {'image_name': '9_1_s.bmp', 'dist': 50951.87211477121},
#  {'image_name': '10_6_s.bmp', 'dist': 51096.07975177743},
#  {'image_name': '10_25_s.bmp', 'dist': 51208.58332350154},
#  {'image_name': '13_2_s.bmp', 'dist': 51363.61722075267},
#  {'image_name': '17_21_s.bmp', 'dist': 51502.9318388769},
#  {'image_name': '16_11_s.bmp', 'dist': 51605.989419833815},
#  {'image_name': '9_25_s.bmp', 'dist': 51649.54987219153},
#  {'image_name': '18_12_s.bmp', 'dist': 51686.83141768317},
#  {'image_name': '17_25_s.bmp', 'dist': 51711.100104329635},
#  {'image_name': '13_22_s.bmp', 'dist': 51750.25878196166},
#  {'image_name': '9_20_s.bmp', 'dist': 51778.288500103976},
#  {'image_name': '10_12_s.bmp', 'dist': 51822.94374116546},
#  {'image_name': '4_3_s.bmp', 'dist': 51906.84773707608},
#  {'image_name': '17_6_s.bmp', 'dist': 51947.0827669851},
#  {'image_name': '11_17_s.bmp', 'dist': 51965.571237118136},
#  {'image_name': '13_4_s.bmp', 'dist': 51999.80276885673},
#  {'image_name': '13_30_s.bmp', 'dist': 52011.822425290964},
#  {'image_name': '10_17_s.bmp', 'dist': 52126.061312936356},
#  {'image_name': '6_21_s.bmp', 'dist': 52335.721089901876},
#  {'image_name': '2_7_s.bmp', 'dist': 52742.29943792743},
#  {'image_name': '2_16_s.bmp', 'dist': 52796.55806963178},
#  {'image_name': '18_29_s.bmp', 'dist': 53000.474846929435},
#  {'image_name': '13_13_s.bmp', 'dist': 53028.101870611965},
#  {'image_name': '1_16_s.bmp', 'dist': 53075.365660539734},
#  {'image_name': '12_22_s.bmp', 'dist': 53272.06812204685},
#  {'image_name': '20_20_s.bmp', 'dist': 53314.66141691233},
#  {'image_name': '10_2_s.bmp', 'dist': 53346.46106350448},
#  {'image_name': '20_6_s.bmp', 'dist': 53416.777102329936},
#  {'image_name': '16_17_s.bmp', 'dist': 53479.58683460447},
#  {'image_name': '13_21_s.bmp', 'dist': 53909.463974333856},
#  {'image_name': '4_18_s.bmp', 'dist': 54162.782794092105},
#  {'image_name': '3_4_s.bmp', 'dist': 54242.26438857434},
#  {'image_name': '20_5_s.bmp', 'dist': 54253.76370354411},
#  {'image_name': '6_5_s.bmp', 'dist': 54503.19632828886},
#  {'image_name': '10_10_s.bmp', 'dist': 54616.147612221794},
#  {'image_name': '2_30_s.bmp', 'dist': 54970.969174647085},
#  {'image_name': '1_24_s.bmp', 'dist': 55028.08332115521},
#  {'image_name': '20_9_s.bmp', 'dist': 55043.84530535635},
#  {'image_name': '20_2_s.bmp', 'dist': 55080.59636568943},
#  {'image_name': '13_1_s.bmp', 'dist': 55201.32116172583},
#  {'image_name': '11_25_s.bmp', 'dist': 55826.560022985475},
#  {'image_name': '7_26_s.bmp', 'dist': 56104.62603030164},
#  {'image_name': '3_6_s.bmp', 'dist': 56441.203495318914},
#  {'image_name': '11_19_s.bmp', 'dist': 56455.912816993754},
#  {'image_name': '17_22_s.bmp', 'dist': 56806.5990708826},
#  {'image_name': '18_30_s.bmp', 'dist': 57149.89140847076},
#  {'image_name': '15_17_s.bmp', 'dist': 57527.25288069995},
#  {'image_name': '16_24_s.bmp', 'dist': 58497.81318989625},
#  {'image_name': '4_1_s.bmp', 'dist': 58558.02696471253},
#  {'image_name': '10_29_s.bmp', 'dist': 58803.52596571059},
#  {'image_name': '17_14_s.bmp', 'dist': 59008.34959562926},
#  {'image_name': '5_17_s.bmp', 'dist': 59145.07857801864},
#  {'image_name': '15_12_s.bmp', 'dist': 59306.562705994016},
#  {'image_name': '10_23_s.bmp', 'dist': 59429.976914012004},
#  {'image_name': '11_27_s.bmp', 'dist': 59548.72666984576},
#  {'image_name': '18_3_s.bmp', 'dist': 59625.943648717206},
#  {'image_name': '19_15_s.bmp', 'dist': 59698.846119502174},
#  {'image_name': '6_9_s.bmp', 'dist': 59879.644304220776},
#  {'image_name': '1_14_s.bmp', 'dist': 60027.59297189918},
#  {'image_name': '11_16_s.bmp', 'dist': 60374.18135262788},
#  {'image_name': '16_12_s.bmp', 'dist': 60505.951690722126},
#  {'image_name': '5_20_s.bmp', 'dist': 60925.06372585916},
#  {'image_name': '16_16_s.bmp', 'dist': 60964.97702779851},
#  {'image_name': '2_25_s.bmp', 'dist': 61127.97876586465},
#  {'image_name': '1_17_s.bmp', 'dist': 61291.503375264016},
#  {'image_name': '16_25_s.bmp', 'dist': 61305.171592615254},
#  {'image_name': '5_23_s.bmp', 'dist': 61589.21728679461},
#  {'image_name': '16_23_s.bmp', 'dist': 62025.77067638902},
#  {'image_name': '2_19_s.bmp', 'dist': 62251.554261721045},
#  {'image_name': '5_29_s.bmp', 'dist': 62277.44973905081},
#  {'image_name': '3_17_s.bmp', 'dist': 62368.44782420034},
#  {'image_name': '14_14_s.bmp', 'dist': 62424.08600852719},
#  {'image_name': '20_10_s.bmp', 'dist': 62555.73347024236},
#  {'image_name': '16_3_s.bmp', 'dist': 62576.89869272846},
#  {'image_name': '2_21_s.bmp', 'dist': 62611.7481947278},
#  {'image_name': '2_29_s.bmp', 'dist': 62759.615135849905},
#  {'image_name': '5_8_s.bmp', 'dist': 62966.00768668758},
#  {'image_name': '4_5_s.bmp', 'dist': 63036.43341750864},
#  {'image_name': '13_6_s.bmp', 'dist': 63161.67681434684},
#  {'image_name': '10_20_s.bmp', 'dist': 63199.940822757104},
#  {'image_name': '18_13_s.bmp', 'dist': 63236.76925650139},
#  {'image_name': '19_19_s.bmp', 'dist': 63798.65224281779},
#  {'image_name': '11_14_s.bmp', 'dist': 63901.42676028447},
#  {'image_name': '12_26_s.bmp', 'dist': 64147.48804123198},
#  {'image_name': '16_15_s.bmp', 'dist': 64543.46433218471},
#  {'image_name': '10_7_s.bmp', 'dist': 64674.511409055114},
#  {'image_name': '11_21_s.bmp', 'dist': 65045.987808626596},
#  {'image_name': '11_18_s.bmp', 'dist': 65230.62046309233},
#  {'image_name': '14_30_s.bmp', 'dist': 65245.08899526462},
#  {'image_name': '6_13_s.bmp', 'dist': 65391.24146244663},
#  {'image_name': '20_17_s.bmp', 'dist': 65401.40688089209},
#  {'image_name': '15_2_s.bmp', 'dist': 66214.81497369},
#  {'image_name': '5_19_s.bmp', 'dist': 66617.02163861725},
#  {'image_name': '14_25_s.bmp', 'dist': 66672.51708162818},
#  {'image_name': '11_13_s.bmp', 'dist': 67557.7100263175},
#  {'image_name': '11_11_s.bmp', 'dist': 67783.36987786902},
#  {'image_name': '10_19_s.bmp', 'dist': 68713.62771677828},
#  {'image_name': '10_11_s.bmp', 'dist': 68837.80669080037},
#  {'image_name': '10_8_s.bmp', 'dist': 68896.78054887615},
#  {'image_name': '15_22_s.bmp', 'dist': 69020.44902780624},
#  {'image_name': '5_25_s.bmp', 'dist': 69594.14749819125},
#  {'image_name': '10_15_s.bmp', 'dist': 69632.27254657139},
#  {'image_name': '9_16_s.bmp', 'dist': 70171.07341348},
#  {'image_name': '2_14_s.bmp', 'dist': 70172.08851103122},
#  {'image_name': '1_12_s.bmp', 'dist': 70442.39054716982},
#  {'image_name': '2_13_s.bmp', 'dist': 70695.34389194242},
#  {'image_name': '10_24_s.bmp', 'dist': 71438.89643604525},
#  {'image_name': '11_9_s.bmp', 'dist': 72475.16894771616},
#  {'image_name': '15_15_s.bmp', 'dist': 72869.94549195161},
#  {'image_name': '14_26_s.bmp', 'dist': 73037.256410684},
#  {'image_name': '12_6_s.bmp', 'dist': 73730.33529016397},
#  {'image_name': '11_1_s.bmp', 'dist': 74497.14938170453},
#  {'image_name': '18_25_s.bmp', 'dist': 75122.75303794451},
#  {'image_name': '18_26_s.bmp', 'dist': 75728.9893765921},
#  {'image_name': '5_26_s.bmp', 'dist': 76519.38066921347},
#  {'image_name': '20_1_s.bmp', 'dist': 76935.8522276838},
#  {'image_name': '12_18_s.bmp', 'dist': 77994.06460750716},
#  {'image_name': '11_20_s.bmp', 'dist': 78216.30424662112},
#  {'image_name': '5_27_s.bmp', 'dist': 78531.57492372097},
#  {'image_name': '12_28_s.bmp', 'dist': 79689.576507847},
#  {'image_name': '11_5_s.bmp', 'dist': 82727.9116622679},
#  {'image_name': '12_17_s.bmp', 'dist': 83010.16225740075},
#  {'image_name': '15_16_s.bmp', 'dist': 83643.08793917164},
#  {'image_name': '11_4_s.bmp', 'dist': 84370.91963467034},
#  {'image_name': '12_15_s.bmp', 'dist': 87890.88831045003},
#  {'image_name': '10_9_s.bmp', 'dist': 88492.98547342609},
#  {'image_name': '12_14_s.bmp', 'dist': 89201.3572430375},
#  {'image_name': '12_7_s.bmp', 'dist': 91160.56312901978},
#  {'image_name': '11_2_s.bmp', 'dist': 91671.00771781665},
#  {'image_name': '11_6_s.bmp', 'dist': 92313.78417116265},
#  {'image_name': '12_8_s.bmp', 'dist': 95049.15984899603},
#  {'image_name': '12_16_s.bmp', 'dist': 102755.2594760969}]

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Assuming top_15 is a list of dictionaries with 'image_name' as a key
top_15 = sorted_list[1:16]

# Increase the figure size for larger images
f, axarr = plt.subplots(1, 15, figsize=(45, 5))  # Adjust as needed

for i, image_dict in enumerate(top_15):
    image_path = DATASET_FOLDER + image_dict['image_name']
    img = mpimg.imread(image_path)  # Load the image
    axarr[i].imshow(img)  # Display the image
    axarr[i].axis('off')  # Turn off axis grid lines
    
    # Label the first image as "Query Image"
    if i == 0:
        axarr[i].set_title("Query Image", fontsize=16)
    else:
        # Label the other images as 1, 2, 3, ..., 15
        axarr[i].set_title(f"{i}", fontsize=16)

plt.tight_layout()  # Adjust layout so images don't overlap
plt.show()

# %%
import cv2
img = cv2.imread('./MSRC_ObjCategImageDatabase_v2/Images/3_17_s.bmp')
gray= cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
 
sift = cv2.SIFT_create()
kp = sift.detect(gray,None)
 
img=cv2.drawKeypoints(gray,kp,img)
 
cv2.imwrite('./sift_test.jpg',img)
